# %%
#%matplotlib inline
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# Load the image and convert to a NumPy array
img = np.asarray(Image.open("C:\\Users\\Alex\\OneDrive\\Code\\ASCII to Image\\image.bmp"))

# Apply the grayscale conversion using the weighted sum
gray_img = np.dot(img[..., :3], [0.299, 0.587, 0.114]).astype(np.uint8)
# convolve = []
# for count1,row in enumerate(gray_img[1:-1]):
#     a = []
#     for count2, column in enumerate(row[1:-1]):
#         a.append(
#             [gray_img[count1+i][count2+j] for i in range(3) for j in range(3)]
#             )
#     convolve.append(a)
        

# Display the grayscale image
plt.imshow(gray_img, cmap='gray')
# plt.imshow(convolve, cmap='gray')
plt.axis('off')  # Hide the axes
plt.show()

# Optionally, save the grayscale image
gray_img_pil = Image.fromarray(gray_img)
gray_img_pil.save("image.bmp")
